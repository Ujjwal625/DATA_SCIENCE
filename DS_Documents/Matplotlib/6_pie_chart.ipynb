# %% [markdown]
# Matplotlib Tutorial: Pie Charts

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Draw pie chart to track down home expenses

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]
plt.pie(exp_vals,labels=exp_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x23404342b80>,
#   <matplotlib.patches.Wedge at 0x23404342fd0>,
#   <matplotlib.patches.Wedge at 0x234049fc4f0>,
#   <matplotlib.patches.Wedge at 0x234049fc9d0>,
#   <matplotlib.patches.Wedge at 0x234049fceb0>],
#  [Text(0.09328656407206024, 1.0960372333838069, 'Home Rent'),
#   Text(-0.9822184890776084, -0.4952240298229684, 'Food'),
#   Text(-0.16284704617934698, -1.0878790555712807, 'Phone/Internet Bill'),
#   Text(0.6256100334857941, -0.9047718419590123, 'Car '),
#   Text(1.0615045230766318, -0.28845822485734873, 'Other Utilities')])

# %% [markdown]
# Draw pie chart as perfect circle

# %%
plt.pie(exp_vals,labels=exp_labels, shadow=True)
plt.axis("equal")
plt.show() #this line hide the extra information like in above code, #[<matplotlib.patches.............

# %% [markdown]
# Show percentages for every pie. Specify radius to increase chart size

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%0.3f%%',radius=1.5)
plt.show()
#autopct stand for auto_percentage, it take no. uptu which % has to be shown

# %% [markdown]
# Explode

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2])
plt.show()

# %% [markdown]
# counterclock and angle properties

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0,0,0,0.1,0.2],counterclock=True, startangle=45)
plt.show()
