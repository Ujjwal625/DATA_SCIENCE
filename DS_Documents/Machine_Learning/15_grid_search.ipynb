# %% [markdown]
# https://github.com/codebasics/py/blob/master/ML/15_gridsearch/15_grid_search.ipynb
#
#     https://www.youtube.com/watch?v=HdlDYng8g9s&list=PLeo1K3hjS3us_ELKYSj_Fth2tIEkdKXvV&index=55

# %% [markdown]
# Finding best model and hyper parameter tunning using GridSearchCV
#
# For iris flower dataset in sklearn library, we are going to find out best model and best hyper parameters using GridSearchCV

# %%
import pandas as pd

# %%
from sklearn import svm, datasets
iris = datasets.load_iris()

# %%
import pandas as pd
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df['flower'] = iris.target
df['flower'] = df['flower'].apply(lambda x: iris.target_names[x])
df[47:150]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 47                 4.6               3.2                1.4               0.2
# 48                 5.3               3.7                1.5               0.2
# 49                 5.0               3.3                1.4               0.2
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          flower
# 47       setosa
# 48       setosa
# 49       setosa
# 50   versicolor
# 51   versicolor
# ..          ...
# 145   virginica
# 146   virginica
# 147   virginica
# 148   virginica
# 149   virginica
#
# [103 rows x 5 columns]

# %% [markdown]
# Approach 1: Use train_test_split and manually tune parameters by trial and error

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3)

# %%
model = svm.SVC(kernel='rbf',C=30,gamma='auto')
model.fit(X_train,y_train)
model.score(X_test, y_test)
# Out:
# 0.9777777777777777

# %% [markdown]
# Approach 2: Use K Fold Cross validation

# %% [markdown]
# Manually try suppling models with different parameters to cross_val_score function with 5 fold cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(svm.SVC(kernel='linear',C=10,gamma='auto'),iris.data, iris.target, cv=5)
# Out:
# array([1.        , 1.        , 0.9       , 0.96666667, 1.        ])

# %%
cross_val_score(svm.SVC(kernel='rbf',C=10,gamma='auto'),iris.data, iris.target, cv=5)
# Out:
# array([0.96666667, 1.        , 0.96666667, 0.96666667, 1.        ])

# %%
cross_val_score(svm.SVC(kernel='rbf',C=20,gamma='auto'),iris.data, iris.target, cv=5)
# Out:
# array([0.96666667, 1.        , 0.9       , 0.96666667, 1.        ])

# %% [markdown]
# Above approach is tiresome and very manual. We can use for loop as an alternative

# %%
kernels = ['rbf', 'linear']
C = [1,10,20]
avg_scores = {}
for kval in kernels:
    for cval in C:
        cv_scores = cross_val_score(svm.SVC(kernel=kval,C=cval,gamma='auto'),iris.data, iris.target, cv=5)
        avg_scores[kval + '_' + str(cval)] = cv_scores.mean()

avg_scores
# Out:
# {'rbf_1': 0.9800000000000001,
#  'rbf_10': 0.9800000000000001,
#  'rbf_20': 0.9666666666666668,
#  'linear_1': 0.9800000000000001,
#  'linear_10': 0.9733333333333334,
#  'linear_20': 0.9666666666666666}

# %% [markdown]
# From above results we can say that rbf with C=1 or 10 or linear with C=1 will give best performance

# %% [markdown]
# Approach 3: Use GridSearchCV
# #GridSearchCV does exactly same thing as for loop above but in a single line of code

# %%
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(svm.SVC(gamma='auto'), {
    'C': [1,10,20],
    'kernel': ['rbf','linear']
}, cv=5, return_train_score=False)
clf.fit(iris.data, iris.target)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00109854, 0.00055075, 0.00064569, 0.00052261, 0.00060172,
#         0.00052094]),
#  'std_fit_time': array([4.37167276e-04, 2.35959725e-05, 3.47991171e-05, 3.14032658e-05,
#         2.03880090e-05, 1.32342715e-05]),
#  'mean_score_time': array([0.00043621, 0.00029998, 0.00030541, 0.0002728 , 0.00029039,
#         0.00026126]),
#  'std_score_time': array([1.41368394e-04, 3.87977873e-05, 7.08388101e-06, 1.16395159e-05,
#         6.81560283e-06, 3.91877762e-06]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'}],
#  'split0_test_score': array([0.96666667, 0.96666667, 0.96666667, 1.        , 0.96666667,
#         1.        ]),
#  'split1_test_score': array([1., 1., 1., 1., 1., 1.]),
#  'split2_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.9       , 0.9       ,
#         0.9       ]),
#  'split3_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.96666667, 0.96666667,
#         0.93333333]),
#  'split4_test_score': array([1., 1., 1., 1., 1., 1.]),
#  'mean_test_score': array([0.98      , 0.98      , 0.98      , 0.97333333, 0.96666667,
#         0.96666667]),
#  'std_test_score': array([0.01632993, 0.01632993, 0.01632993, 0.03887301, 0.03651484,
#         0.0421637 ]),
#  'rank_test_score': array([1, 1, 1, 4, 5, 6], dtype=int32)}

# %%
df = pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.001099      0.000437         0.000436        0.000141       1
# 1       0.000551      0.000024         0.000300        0.000039       1
# 2       0.000646      0.000035         0.000305        0.000007      10
# 3       0.000523      0.000031         0.000273        0.000012      10
# 4       0.000602      0.000020         0.000290        0.000007      20
# 5       0.000521      0.000013         0.000261        0.000004      20
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# 5       linear  {'C': 20, 'kernel': 'linear'}           1.000000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
# 2                1.0           0.966667           0.966667                1.0
# 3                1.0           0.900000           0.966667                1.0
# 4                1.0           0.900000           0.966667                1.0
# 5                1.0           0.900000           0.933333                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.980000        0.016330                1
# 1         0.980000        0.016330                1
# 2         0.980000        0.016330                1
# 3         0.973333        0.038873                4
# 4         0.966667        0.036515                5
# 5         0.966667        0.042164                6

# %%
df[['param_C','param_kernel','mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1          rbf         0.980000
# 1       1       linear         0.980000
# 2      10          rbf         0.980000
# 3      10       linear         0.973333
# 4      20          rbf         0.966667
# 5      20       linear         0.966667

# %%
clf.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
clf.best_score_
# Out:
# 0.9800000000000001

# %%
dir(clf)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_feature_names',
#  '_check_n_features',
#  '_check_refit_for_multimetric',
#  '_estimator_type',
#  '_format_results',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_pairwise',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_required_parameters',
#  '_run_search',
#  '_select_best_index',
#  '_validate_data',
#  'best_estimator_',
#  'best_index_',
#  'best_params_',
#  'best_score_',
#  'classes_',
#  'cv',
#  'cv_results_',
#  'decision_function',
#  'error_score',
#  'estimator',
#  'fit',
#  'get_params',
#  'inverse_transform',
#  'multimetric_',
#  'n_features_in_',
#  'n_jobs',
#  'n_splits_',
#  'param_grid',
#  'pre_dispatch',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'refit',
#  'refit_time_',
#  'return_train_score',
#  'score',
#  'score_samples',
#  'scorer_',
#  'scoring',
#  'set_params',
#  'transform',
#  'verbose']

# %% [markdown]
# Use RandomizedSearchCV to reduce number of iterations and with random combination of parameters.
# This is useful when you have too many parameters to try and your training time is longer.
# It helps reduce the cost of computation

# %%
from sklearn.model_selection import RandomizedSearchCV
rs = RandomizedSearchCV(svm.SVC(gamma='auto'), {
        'C': [1,10,20],
        'kernel': ['rbf','linear']
    }, 
    cv=5, 
    return_train_score=False, 
    n_iter=2
)
rs.fit(iris.data, iris.target)
pd.DataFrame(rs.cv_results_)[['param_C','param_kernel','mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0      10          rbf             0.98
# 1       1          rbf             0.98

# %% [markdown]
# How about different models with different hyperparameters?

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    }
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(iris.data, iris.target)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score                best_params
# 0                  svm    0.980000  {'C': 1, 'kernel': 'rbf'}
# 1        random_forest    0.953333        {'n_estimators': 1}
# 2  logistic_regression    0.966667                   {'C': 5}

# %% [markdown]
# Based on above, I can conclude that SVM with C=1 and kernel='rbf' is the best model
# for solving my problem of iris flower classification

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {                            # here we can increse the no. of parameter according to our choices
           'C':[0.1,1,100,1000],
               'kernel':['rbf','poly','sigmoid','linear'],
               'degree':[1,2,3,4,5,6]
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
#             'n_estimators': [1,5,10],
#             'max_depth':[3,5,7,10,15],
#           'min_samples_leaf':[3,5,10,15,20],
#           'min_samples_split':[8,10,12,18,20,16],         
#           'criterion':['gini','entropy','log_loss'],
#           'splitter':['best','random'],
#           'max_features':['auto', 'sqrt', 'log2']
#             'criterion':['gini','entropy','log_loss'],
#   'splitter':['best','random'],
#   'max_depth':[1,2,3,4,5],
#   'max_features':['auto', 'sqrt', 'log2']
            'max_depth':[3,5,7,10,15],
          'min_samples_leaf':[3,5,10,15,20],
          'min_samples_split':[8,10,12,18,20,16],
          'criterion':['gini','entropy']
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    }
}

# %%
## here basically we run a loop and in final we get about gridserach cv result of every model parameters
scores = [] 
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'],n_jobs=-1,cv=5, return_train_score=False,verbose=2)
    clf.fit(iris.data, iris.target)
    score1=cross_val_score(mp['model'], iris.data, iris.target,cv=5)
    score1.mean()
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_,
        'cross_val_Score': score1.mean()
    })

 #the whole inforamtion we get here is just becos of using verbose=2
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# [CV] END ........................C=0.1, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ....................C=0.1, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, degree=2, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=2, kernel=linear; total time=   0.0s
# [CV] END .......................C=0.1, degree=3, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=3, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, degree=3, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=3, kernel=linear; total time=   0.0s
# [CV] END ........................C=0.1, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ....................C=0.1, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, degree=6, kernel=linear; total time=   0.0s
# [CV] END ..........................C=1, degree=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, degree=1, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=1, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=1, kernel=poly; total time=   0.0s
# [CV] END .......................C=1, degree=1, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=1, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=1, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=1, kernel=linear; total time=   0.0s
# [CV] END ..........................C=1, degree=2, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=2, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=2, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=2, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, degree=3, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=3, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=3, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=3, kernel=linear; total time=   0.0s
# [CV] END ..........................C=1, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=4, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, degree=5, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=5, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=5, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=5, kernel=linear; total time=   0.0s
# [CV] END ..........................C=1, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, degree=1, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=1, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=1, kernel=poly; total time=   0.0s
# [CV] END .....................C=100, degree=1, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=1, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=1, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=1, kernel=linear; total time=   0.0s
# [CV] END ........................C=100, degree=2, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=2, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=2, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=2, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=3, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=3, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=3, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=3, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=3, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   0.1s
# [CV] END ....................C=100, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, degree=3, kernel=linear; total time=   0.0s
# [CV] END ........................C=100, degree=6, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, degree=6, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=6, kernel=poly; total time=   0.5s
# [CV] END .......................C=100, degree=6, kernel=poly; total time=   0.2s
# [CV] END .......................C=100, degree=6, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=6, kernel=poly; total time=   0.3s
# [CV] END ....................C=100, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, degree=6, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=6, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=6, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=6, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=6, kernel=linear; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END ........................C=0.1, degree=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, degree=1, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=1, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, degree=1, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=1, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=1, kernel=linear; total time=   0.0s
# [CV] END ........................C=0.1, degree=2, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=2, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, degree=2, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ........................C=0.1, degree=3, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, degree=3, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ........................C=0.1, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=4, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, degree=4, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=4, kernel=poly; total time=   0.0s
# [CV] END .....................C=0.1, degree=5, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=5, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=5, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=5, kernel=linear; total time=   0.0s
# [CV] END .......................C=0.1, degree=6, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=6, kernel=poly; total time=   0.5s
# [CV] END ....................C=0.1, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=1000, degree=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1000, degree=1, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=1, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=1, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=1, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=1, kernel=poly; total time=   0.0s
# [CV] END ...................C=1000, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1000, degree=1, kernel=linear; total time=   0.0s
# [CV] END ...................C=1000, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1000, degree=2, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=2, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=2, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=2, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=2, kernel=linear; total time=   0.0s
# [CV] END .......................C=1000, degree=3, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=3, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=3, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=3, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=3, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=   0.2s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=   0.1s
# [CV] END ...................C=1000, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1000, degree=4, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=4, kernel=linear; total time=   0.0s
# [CV] END .......................C=1000, degree=5, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1000, degree=5, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=5, kernel=poly; total time=   0.2s
# [CV] END ...................C=1000, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1000, degree=6, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=6, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=6, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=6, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=6, kernel=linear; total time=   0.0s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END ........................C=0.1, degree=1, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, degree=1, kernel=linear; total time=   0.0s
# [CV] END ........................C=0.1, degree=2, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=2, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, degree=2, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=2, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, degree=2, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=2, kernel=linear; total time=   0.0s
# [CV] END ........................C=0.1, degree=3, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=3, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, degree=3, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=3, kernel=poly; total time=   0.0s
# [CV] END .....................C=0.1, degree=3, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=3, kernel=linear; total time=   0.0s
# [CV] END .......................C=0.1, degree=4, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=4, kernel=poly; total time=   0.0s
# [CV] END .....................C=0.1, degree=4, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=4, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=4, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=4, kernel=linear; total time=   0.0s
# [CV] END ....................C=0.1, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, degree=5, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=6, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=6, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=6, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, degree=6, kernel=linear; total time=   0.0s
# [CV] END .........................C=1, degree=1, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=1, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ..........................C=1, degree=3, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=3, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=3, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=3, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=3, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.0s
# [CV] END ..........................C=1, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=5, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, degree=5, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=5, kernel=poly; total time=   0.2s
# [CV] END .........................C=1, degree=5, kernel=poly; total time=   0.2s
# [CV] END ....................C=1000, degree=1, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=1, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=1, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=1, kernel=linear; total time=   0.0s
# [CV] END .......................C=1000, degree=2, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=2, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=2, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=2, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=2, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=   0.0s
# [CV] END ...................C=1000, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=   0.3s
# [CV] END ...................C=1000, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1000, degree=4, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=4, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=4, kernel=linear; total time=   0.0s
# [CV] END .......................C=1000, degree=5, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=5, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1000, degree=5, kernel=poly; total time=   0.3s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=16; total time=   0.3s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END .......................C=0.1, degree=1, kernel=poly; total time=   0.0s
# [CV] END ..........................C=1, degree=2, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ..........................C=1, degree=4, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ........................C=100, degree=2, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   0.0s
# [CV] END ....................C=100, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, degree=2, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=2, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=2, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=2, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=2, kernel=linear; total time=   0.0s
# [CV] END ....................C=100, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, degree=4, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=4, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=4, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=4, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=4, kernel=linear; total time=   0.0s
# [CV] END ........................C=100, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=5, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=5, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, degree=5, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=5, kernel=poly; total time=   0.3s
# [CV] END .......................C=100, degree=5, kernel=poly; total time=   0.2s
# [CV] END ...................C=1000, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1000, degree=3, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=3, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=3, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=3, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=3, kernel=linear; total time=   0.0s
# [CV] END .......................C=1000, degree=4, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=   0.2s
# [CV] END .......................C=1000, degree=6, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=6, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1000, degree=6, kernel=poly; total time=   0.3s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=10; total time=   0.3s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=20; total time=   0.3s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END .......................C=0.1, degree=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, degree=5, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.0s
# [CV] END ..........................C=1, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=1, degree=1, kernel=linear; total time=   0.0s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=3, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=1, degree=3, kernel=linear; total time=   0.0s
# [CV] END ......................C=1, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=6, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=1, degree=6, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=6, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=6, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=6, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, degree=6, kernel=linear; total time=   0.0s
# [CV] END .......................C=100, degree=1, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=1, kernel=poly; total time=   0.0s
# [CV] END ....................C=100, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, degree=1, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=3, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=3, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=3, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=3, kernel=linear; total time=   0.0s
# [CV] END ........................C=100, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=4, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   0.3s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   0.2s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   0.3s
# [CV] END ....................C=100, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1000, degree=5, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=5, kernel=poly; total time=   0.4s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=10, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END ........................C=0.1, degree=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, degree=4, kernel=rbf; total time=   0.0s
# [CV] END ....................C=0.1, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=4, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.1s
# [CV] END ....................C=0.1, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END .........................C=1, degree=5, kernel=poly; total time=   0.0s
# [CV] END .........................C=1, degree=5, kernel=poly; total time=   0.1s
# [CV] END ......................C=1, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=1, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=1, degree=5, kernel=linear; total time=   0.0s
# [CV] END .......................C=100, degree=5, kernel=poly; total time=   0.0s
# [CV] END .......................C=100, degree=5, kernel=poly; total time=   0.7s
# [CV] END ....................C=100, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=100, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, degree=5, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=5, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=5, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=5, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, degree=5, kernel=linear; total time=   0.0s
# [CV] END ........................C=100, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ...................C=1000, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1000, degree=5, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1000, degree=5, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=5, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=5, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=5, kernel=linear; total time=   0.0s
# [CV] END ....................C=1000, degree=5, kernel=linear; total time=   0.0s
# [CV] END .......................C=1000, degree=6, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1000, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1000, degree=6, kernel=poly; total time=   0.0s
# [CV] END ......................C=1000, degree=6, kernel=poly; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=10; total time=   0.3s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=8; total time=   0.3s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=3, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=10, min_samples_split=12; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# ...
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=18; total time=   0.3s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=16; total time=   0.3s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=20; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=16; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=16; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=18; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=8; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=15, min_samples_split=10; total time=   0.3s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=10; total time=   0.3s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=16; total time=   0.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=10; total time=   0.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=18; total time=   0.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=12; total time=   0.3s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=12; total time=   0.3s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=12; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# Fitting 5 folds for each of 3 candidates, totalling 15 fits

# %%
   
df = pd.DataFrame(scores,columns=['model','best_score','best_params','score1'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.986667
# 1        random_forest    0.966667
# 2  logistic_regression    0.966667
#
#                                          best_params  score1
# 0          {'C': 0.1, 'degree': 2, 'kernel': 'poly'}     NaN
# 1  {'criterion': 'gini', 'max_depth': 7, 'min_sam...     NaN
# 2                                           {'C': 5}     NaN

# %%
from sklearn.svm import SVC
svm = SVC(gamma='auto')

# %%
scores1=cross_val_score(SVC(gamma='auto',kernel='poly',degree=2,C=0.1), iris.data, iris.target,cv=7)
scores1.mean()
# Out:
# 0.9802102659245516

# %%
## here basically we run a loop and in final we get about gridserach cv result of every model parameters
scores = [] 
for model_name, mp in model_params.items():
    rs =  RandomizedSearchCV(mp['model'], mp['params'],n_jobs=-1,cv=5, return_train_score=False,verbose=2)
    rs.fit(iris.data, iris.target)
    score1=cross_val_score(mp['model'], iris.data, iris.target,cv=5)
    score1.mean()
    scores.append({
        'model': model_name,
        'best_score': rs.best_score_,
        'best_params': rs.best_params_,
        'cross_val_Score': score1.mean()
    })

 #the whole inforamtion we get here is just becos of using verbose=2
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=18; total time=   0.3s
# [CV] END criterion=entropy, max_depth=3, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=18; total time=   0.3s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=12; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=10; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=15, min_samples_split=16; total time=   0.3s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END .......................C=0.1, degree=2, kernel=poly; total time=   0.0s
# [CV] END ....................C=100, degree=2, kernel=sigmoid; total time=   0.0s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=5, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=10; total time=   0.3s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=3, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=12; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=5, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=8; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=10, min_samples_split=16; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=15, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=15, min_samples_split=18; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=15, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=20, min_samples_split=8; total time=   0.3s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=20, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=20, min_samples_split=20; total time=   0.2s
# [CV] END criterion=entropy, max_depth=15, min_samples_leaf=20, min_samples_split=16; total time=   0.2s
# [CV] END ................................................C=5; total time=   0.0s
# [CV] END ................................................C=5; total time=   0.0s
# [CV] END ................................................C=5; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ........................C=0.1, degree=6, kernel=rbf; total time=   0.0s
# [CV] END ....................C=100, degree=2, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.0s
# [CV] END .......................C=0.1, degree=5, kernel=poly; total time=   0.0s
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# /home/ujjwal/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:292: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(

# %%
RS_df = pd.DataFrame(scores,columns=['model','best_score','best_params','score1'])
RS_df
# Out:
#                  model  best_score  \
# 0                  svm    0.986667
# 1        random_forest    0.966667
# 2  logistic_regression    0.966667
#
#                                          best_params  score1
# 0          {'kernel': 'poly', 'degree': 2, 'C': 0.1}     NaN
# 1  {'min_samples_split': 12, 'min_samples_leaf': ...     NaN
# 2                                           {'C': 5}     NaN
